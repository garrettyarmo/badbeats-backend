# %%
import pandas as pd
from tabulate import tabulate
import requests, json, sys, os, re
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from plumbing.natstat_ingestion import ingest_teams_data, ingest_players_data, ingest_games_data, parse_game_data

# %% [markdown]
# ### Base Games (schedule) table; filter on 'status', 'gameday', 'starttime' for various use cases
# `currently only getting 2024 games`

# %% [markdown]
# ## Roadmap
# - get Teams table
# - get list of teamID's
# - - for each ID in teamIDs get players (into Players Table)
# - get list of playerID's
# - - for each ID in playerIDs get statlines for (how many seasons??)

# %%
def main():
    """Pickles core DFs for development - only run when necessary"""
    games_df = ingest_games_data()
    games_df.to_pickle('dataframes/games.pkl')
    teams_df = ingest_teams_data()
    teams_df.to_pickle('dataframes/teams.pkl')
    players_df = ingest_players_data(teams_df)
    players_df.to_pickle('dataframes/players.pkl')

if __name__ == '__main__':
    main()

# %%
games_df = ingest_games_data()
team_df = ingest_teams_data()

print(tabulate(team_df, headers='keys', tablefmt='fancy_grid'))
print(tabulate(games_df, headers='keys', tablefmt='fancy_grid'))
# Out:
# ╒════╤═══════════╤═══════════════╤═════════════════╤═══════════════════════╤═════════════╤══════════════════════════════════════╤════════════════════════════════════════════════════╕
# │    │   team_id │ team_name     │ team_nickname   │ team_fullname         │ team_code   │ api_url                              │ site_url                                           │
# ╞════╪═══════════╪═══════════════╪═════════════════╪═══════════════════════╪═════════════╪══════════════════════════════════════╪════════════════════════════════════════════════════╡
# │  0 │   2022578 │ Buffalo       │ Bills           │ Buffalo Bills         │ BUF         │ https://interst.at/team/pfb/buf,2024 │ https://natstat.com/pfb/team/buffalo-bills         │
# ├────┼───────────┼───────────────┼─────────────────┼───────────────────────┼─────────────┼──────────────────────────────────────┼────────────────────────────────────────────────────┤
# ...
